# %%
# Mount Google Drive to access files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define paths for the zip file and extraction directory
zip_path = '/content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/Dataset.zip'
extract_path = '/content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/Dataset'

# %%
import zipfile
import os

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

    print(f'Files extracted')
# Out:
# Files extracted

# %%
data_yaml = """
path: /content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/Dataset/dataset
train: /content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/Dataset/dataset/train
val: /content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/Dataset/dataset/val

nc: 3
names: ['P', 'QRS', 'T']
"""

with open('/content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/Dataset/data.yaml', 'w') as f:
    f.write(data_yaml)
    print("data.yaml created successfully!")
# Out:
# data.yaml created successfully!

# %%
# Install Ultralytics YOLO
# !pip install ultralytics

# Import the YOLO library
from ultralytics import YOLO

# Load a pre-trained YOLOv11 model
model = YOLO('yolo11n.pt')  # Pre-trained YOLOv11 model
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 83.8MB/s]

# %%
# Train the custom YOLOv11 model on your dataset
model.train(data='/content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/Dataset/data.yaml', epochs=20, imgsz=416, batch=16)
# Out:
# New https://pypi.org/project/ultralytics/8.3.50 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# Evaluate the model on the validation dataset
val_metrics = model.val(
    data='/content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/Dataset/data.yaml'  # Path to the data file
)

# Display the results
print(val_metrics)
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/Dataset/dataset/val/labels.cache... 600 images, 0 backgrounds, 0 corrupt: 100%|██████████| 600/600 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 38/38 [01:26<00:00,  2.27s/it]
#                    all        600       1541      0.946      0.863       0.93       0.44
#                      P        523        525      0.938      0.869       0.94      0.402
#                    QRS        598        609      0.956      0.967      0.981      0.543
#                      T        407        407      0.945      0.755      0.868      0.374
# Speed: 1.3ms preprocess, 121.3ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs/detect/train22
# ...

# %%
# Save the trained model
model.save('/content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/saved_model.pt', task='detect')

# %%
import os
import random
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt

# Load the YOLO model
model = YOLO('/content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/saved_model.pt', task='detect')

# Path to the directory containing test images
test_images_path = '/content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/Dataset/dataset/test/images'

# Get a list of all image files in the directory
image_files = [f for f in os.listdir(test_images_path) if f.endswith(('.jpg', '.png', '.jpeg'))]

# Select a number of random images (e.g., 5 images)
num_random_images = 5
random_images = random.sample(image_files, num_random_images)

# Get the full paths of the selected random images
random_image_paths = [os.path.join(test_images_path, img) for img in random_images]

# Print the selected images
print(f"Randomly selected images: {random_images}")

# Perform prediction and display the results for each selected image
for image_path in random_image_paths:
    # Perform prediction
    results = model.predict(image_path, save=True)  # Saves the image with bounding boxes

    # Load the saved image with predictions
    result_image_path = results[0].path  # This gets the path of the saved image with predictions
    predicted_image = cv2.imread(result_image_path)
    predicted_image = cv2.cvtColor(predicted_image, cv2.COLOR_BGR2RGB)  # Convert to RGB for display

    # Get prediction details (boxes, class IDs, etc.)
    boxes = results[0].boxes.xyxy  # Bounding boxes (xyxy format)
    class_ids = results[0].boxes.cls  # Class IDs for the predictions
    confidences = results[0].boxes.conf  # Confidence scores for each prediction
    class_names = model.names  # Get the class names

    # Loop through each prediction and draw the bounding box with class name
    for box, class_id, confidence in zip(boxes, class_ids, confidences):
        x1, y1, x2, y2 = map(int, box)  # Get the coordinates of the bounding box
        class_name = class_names[int(class_id)]  # Get the class name
        label = f"{class_name} ({confidence:.2f})"  # Prepare label with class and confidence score

        # Draw the bounding box and label on the image
        cv2.rectangle(predicted_image, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(predicted_image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Display the image with predictions
    plt.figure(figsize=(6, 6))
    plt.imshow(predicted_image)
    plt.axis('off')
    plt.show()

    # Optionally, print the results (predictions)
    print(f"Prediction results for {image_path}:")
    print(results)
# Out:
# Randomly selected images: ['V291.png', 'S2768.png', 'V2491.png', 'Q1857.png', 'Q148.png']
#
# image 1/1 /content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/Dataset/dataset/test/images/V291.png: 640x640 1 QRS, 1 T, 212.4ms
# Speed: 3.4ms preprocess, 212.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict9
# Prediction results for /content/drive/MyDrive/Colab Notebooks/YOLOv11 ECG Dataset/Dataset/dataset/test/images/V291.png:
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'P', 1: 'QRS', 2: 'T'}
# obb: None
# orig_img: array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
# ...
